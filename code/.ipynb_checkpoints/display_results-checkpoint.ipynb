# %%
import torch
loss_train = torch.load('../checkpoint/train_loss.pt')
loss_vald = torch.load('../checkpoint/validation_loss.pt')
vald_accuracy = torch.load('../checkpoint/validation_accuracy.pt')

# %%
import matplotlib.pyplot as plt
plt.plot(loss_train)

# %%
plt.plot(loss_vald)

# %%
plt.plot(vald_accuracy)

# %%
test_res = torch.load('../results/result_dict.pt')

# %%
test_res
# Out:
# {'auc_vals': [0.5146777493543169],
#  'optim_threshold': [0.45243645],
#  'optim_tpr': [0.7462311557788944],
#  'optim_fpr': [0.6675649191572759]}
